# %% [markdown]
# **First class of sql**

# %%
# %sql
DROP TABLE IF EXISTS customer_details;
CREATE TABLE customer_details(
    id INT PRIMARY KEY,
    name VARCHAR(50),
    email VARCHAR(50)
);
INSERT INTO customer_details(id, name, email)
    VALUES(1,'Sahili Subedar','sahili@gmail.com'),
            (2,'Arjun Subedar','arjun@yahoo.com'),
            (3,'Priya Subedar','priya@hotmail.com');    
SELECT * FROM customer_details;
