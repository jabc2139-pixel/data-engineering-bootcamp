# %% [markdown]
# ##### The Python we are going to learn is specifically for Data Engineering not for programing

# %% [markdown]
# - Read Data
# - Validate Data
# - Clean Data
# - Automate repetative Task or work
# - Call APIs
# - Process Files
# - Connect Databases
# - Build Data Pipelines
# - Handle pipelines failures
